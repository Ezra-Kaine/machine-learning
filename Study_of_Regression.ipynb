# %% [markdown]
# <a href="https://colab.research.google.com/github/Ezra-Kaine/machine-learning/blob/main/Study_of_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score

# %%
diabetes_X, diabetes_y = datasets.load_diabetes(return_X_y=True)
diabetes_X=diabetes_X[:,np.newaxis,2]
diabetes_X_train = diabetes_X[:-20]
diabetes_X_test = diabetes_X[-20:]

diabetes_y_train = diabetes_y[:-20]
diabetes_y_test = diabetes_y[-20:]

regr=linear_model.LinearRegression()
regr.fit(diabetes_X_train,diabetes_y_train)
# Out:
# LinearRegression()

# %%
diabetes_y_pred=regr.predict(diabetes_X_test)

# %%
print(f'coefficient:\n {regr.coef_}')
# Out:
# coefficient:
#  [938.23786125]

# %%
(f'Mean squared error: {mean_squared_error(diabetes_y_test,diabetes_y_pred)}')
# Out:
# 'Mean squared error: \n 2548.07239872597'

# %%
print(f'coefficient of determination: \n {r2_score(diabetes_y_test,diabetes_y_pred)}')
# Out:
# coefficient of determination:
#  0.47257544798227147

# %%
plt.scatter(diabetes_X_test,diabetes_y_test,color='black')
plt.plot(diabetes_X_test,diabetes_y_pred)
